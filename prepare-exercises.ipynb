# %% [markdown]
# ### Prepare Exercises
#
# The end result of this exercise should be a file named prepare.py.
#
# Using your store items data:
#
# **1. Convert date column to datetime format.**

# %%
import pandas as pd
import matplotlib.pyplot as plt

def get_sales_data():
    '''
    This function reads the sales_data.csv and returns the data in a pandas dataframe.
    '''
    df = pd.read_csv('sales_data.csv')
    return df

df = get_sales_data()
df.head()
# Out:
#    sale_amount                      sale_date  sale_id  \
# 0         13.0  Tue, 01 Jan 2013 00:00:00 GMT        1
# 1         11.0  Wed, 02 Jan 2013 00:00:00 GMT        2
# 2         14.0  Thu, 03 Jan 2013 00:00:00 GMT        3
# 3         13.0  Fri, 04 Jan 2013 00:00:00 GMT        4
# 4         10.0  Sat, 05 Jan 2013 00:00:00 GMT        5
#
#             store_address   store_city  store_id store_state  store_zipcode  \
# 0  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 1  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 2  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 3  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
# 4  12125 Alamo Ranch Pkwy  San Antonio         1          TX          78253
#
#   item_brand  item_id                       item_name  item_price  \
# 0   Riceland        1  Riceland American Jazmine Rice        0.84
# 1   Riceland        1  Riceland American Jazmine Rice        0.84
# 2   Riceland        1  Riceland American Jazmine Rice        0.84
# 3   Riceland        1  Riceland American Jazmine Rice        0.84
# 4   Riceland        1  Riceland American Jazmine Rice        0.84
#
#     item_upc12   item_upc14
# 0  35200264013  35200264013
# 1  35200264013  35200264013
# 2  35200264013  35200264013
# 3  35200264013  35200264013
# 4  35200264013  35200264013

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 913000 entries, 0 to 912999
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   sale_amount    913000 non-null  float64
#  1   sale_date      913000 non-null  object
#  2   sale_id        913000 non-null  int64
#  3   store_address  913000 non-null  object
#  4   store_city     913000 non-null  object
#  5   store_id       913000 non-null  int64
#  6   store_state    913000 non-null  object
#  7   store_zipcode  913000 non-null  int64
#  8   item_brand     913000 non-null  object
#  9   item_id        913000 non-null  int64
#  10  item_name      913000 non-null  object
#  11  item_price     913000 non-null  float64
#  12  item_upc12     913000 non-null  int64
#  13  item_upc14     913000 non-null  int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 97.5+ MB

# %% [markdown]
# **2. Plot the distribution of sale_amount and item_price.**

# %%
def plot_sales_items():
    '''
    This function plots distribution of sale_amount and item_price
    '''
    #set figure size
    plt.figure(figsize=(20, 5))
    
    #create first subplot (sales amounts)
    plt.subplot(121)
    df['sale_amount'].plot.hist(color = 'lightgreen', edgecolor = 'darkblue')
    plt.title('Distribution of Sale Amounts')
    plt.xlabel('Number of Items Sold')
    
    #create second subplot (item prices)
    plt.subplot (122)
    df['item_price'].plot.hist(color = 'lightgreen', edgecolor = 'darkblue')
    plt.title('Distribution of Item Prices')
    plt.xlabel('Price in Dollars')
    plt.show()
    return

plot_sales_items()

# %% [markdown]
# **3. Set the index to be the datetime variable.**

# %%
def datetime(df, col):
    '''
    This function takes in a dataframe and column name. It returns the dataframe with the index reset to the given column as a datetime variable.  
    '''
    # change data type of column to a datetime variable
    df[col] = pd.to_datetime(df[col])
    
    #set column as the df index
    data = df.set_index(col).sort_index()
    
    return data

df = datetime(df, 'sale_date')

df.head()
# Out:
#                            sale_amount  sale_id           store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0        1  12125 Alamo Ranch Pkwy
# 2013-01-01 00:00:00+00:00         26.0   211817  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         27.0   832657  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         54.0   213643     15000 San Pedro Ave
# 2013-01-01 00:00:00+00:00         35.0   215469      735 SW Military Dr
#
#                             store_city  store_id store_state  store_zipcode  \
# sale_date
# 2013-01-01 00:00:00+00:00  San Antonio         1          TX          78253
# 2013-01-01 00:00:00+00:00  San Antonio         7          TX          78217
# 2013-01-01 00:00:00+00:00  San Antonio         7          TX          78217
# 2013-01-01 00:00:00+00:00  San Antonio         8          TX          78232
# 2013-01-01 00:00:00+00:00  San Antonio         9          TX          78221
#
#                            item_brand  item_id  \
# sale_date
# 2013-01-01 00:00:00+00:00    Riceland        1
# 2013-01-01 00:00:00+00:00     Mueller       12
# 2013-01-01 00:00:00+00:00  Mama Marys       46
# 2013-01-01 00:00:00+00:00     Mueller       12
# 2013-01-01 00:00:00+00:00     Mueller       12
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00                                        Pizza Sauce
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
#
#                            item_price   item_upc12   item_upc14
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        4.65  35457770664  35457770664
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211

# %% [markdown]
# **4. Add a 'month' and 'day of week' column to your dataframe.**

# %%
def month_day():
    '''
    This function adds a column specifying month and weekday based on the index value.
    '''
    df['month'] = df.index.month
    df['day_of_week'] = df.index.day_name()
    return df

df = month_day()
df.head()
# Out:
#                            sale_amount  sale_id           store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0        1  12125 Alamo Ranch Pkwy
# 2013-01-01 00:00:00+00:00         26.0   211817  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         27.0   832657  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         54.0   213643     15000 San Pedro Ave
# 2013-01-01 00:00:00+00:00         35.0   215469      735 SW Military Dr
#
#                             store_city  store_id store_state  store_zipcode  \
# sale_date
# 2013-01-01 00:00:00+00:00  San Antonio         1          TX          78253
# 2013-01-01 00:00:00+00:00  San Antonio         7          TX          78217
# 2013-01-01 00:00:00+00:00  San Antonio         7          TX          78217
# 2013-01-01 00:00:00+00:00  San Antonio         8          TX          78232
# 2013-01-01 00:00:00+00:00  San Antonio         9          TX          78221
#
#                            item_brand  item_id  \
# sale_date
# 2013-01-01 00:00:00+00:00    Riceland        1
# 2013-01-01 00:00:00+00:00     Mueller       12
# 2013-01-01 00:00:00+00:00  Mama Marys       46
# 2013-01-01 00:00:00+00:00     Mueller       12
# 2013-01-01 00:00:00+00:00     Mueller       12
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00                                        Pizza Sauce
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
#
#                            item_price   item_upc12   item_upc14  month  \
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013      1
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211      1
# 2013-01-01 00:00:00+00:00        4.65  35457770664  35457770664      1
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211      1
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211      1
#
#                           day_of_week
# sale_date
# 2013-01-01 00:00:00+00:00     Tuesday
# 2013-01-01 00:00:00+00:00     Tuesday
# 2013-01-01 00:00:00+00:00     Tuesday
# 2013-01-01 00:00:00+00:00     Tuesday
# 2013-01-01 00:00:00+00:00     Tuesday

# %% [markdown]
# 5. Add a column to your dataframe, sales_total, which is a derived from sale_amount (total items) and item_price.

# %%
def add_total():
    
    '''
    This function adds a column for total amount of sale. 
    '''
    df['sale_total'] = df.sale_amount * df.item_price
    return df

df = add_total()
df.head()
# Out:
#                            sale_amount  sale_id           store_address  \
# sale_date
# 2013-01-01 00:00:00+00:00         13.0        1  12125 Alamo Ranch Pkwy
# 2013-01-01 00:00:00+00:00         26.0   211817  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         27.0   832657  12018 Perrin Beitel Rd
# 2013-01-01 00:00:00+00:00         54.0   213643     15000 San Pedro Ave
# 2013-01-01 00:00:00+00:00         35.0   215469      735 SW Military Dr
#
#                             store_city  store_id store_state  store_zipcode  \
# sale_date
# 2013-01-01 00:00:00+00:00  San Antonio         1          TX          78253
# 2013-01-01 00:00:00+00:00  San Antonio         7          TX          78217
# 2013-01-01 00:00:00+00:00  San Antonio         7          TX          78217
# 2013-01-01 00:00:00+00:00  San Antonio         8          TX          78232
# 2013-01-01 00:00:00+00:00  San Antonio         9          TX          78221
#
#                            item_brand  item_id  \
# sale_date
# 2013-01-01 00:00:00+00:00    Riceland        1
# 2013-01-01 00:00:00+00:00     Mueller       12
# 2013-01-01 00:00:00+00:00  Mama Marys       46
# 2013-01-01 00:00:00+00:00     Mueller       12
# 2013-01-01 00:00:00+00:00     Mueller       12
#
#                                                                    item_name  \
# sale_date
# 2013-01-01 00:00:00+00:00                     Riceland American Jazmine Rice
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00                                        Pizza Sauce
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
# 2013-01-01 00:00:00+00:00  Mueller Sport Care Basic Support Level Medium ...
#
#                            item_price   item_upc12   item_upc14  month  \
# sale_date
# 2013-01-01 00:00:00+00:00        0.84  35200264013  35200264013      1
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211      1
# 2013-01-01 00:00:00+00:00        4.65  35457770664  35457770664      1
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211      1
# 2013-01-01 00:00:00+00:00        8.40  74676640211  74676640211      1
#
#                           day_of_week  sale_total
# sale_date
# 2013-01-01 00:00:00+00:00     Tuesday       10.92
# 2013-01-01 00:00:00+00:00     Tuesday      218.40
# 2013-01-01 00:00:00+00:00     Tuesday      125.55
# 2013-01-01 00:00:00+00:00     Tuesday      453.60
# 2013-01-01 00:00:00+00:00     Tuesday      294.00

# %% [markdown]
# 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.

# %% [markdown]
# ### Using the OPS data acquired in the Acquire exercises opsd_germany_daily.csv, complete the following:

# %%
import acquire

ops = acquire.get_ops()
ops.head()
# Out:
#          Date  Consumption  Wind  Solar  Wind+Solar
# 0  2006-01-01     1069.184   NaN    NaN         NaN
# 1  2006-01-02     1380.521   NaN    NaN         NaN
# 2  2006-01-03     1442.533   NaN    NaN         NaN
# 3  2006-01-04     1457.217   NaN    NaN         NaN
# 4  2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# 1. Convert date column to datetime format.

# %%
# Run function that was set in exercise #3, above
ops = datetime(ops, 'Date')
ops.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# 2. Plot the distribution of each of your variables.

# %%
def plot_dist():
    
    '''
    This function plots distribution of consumption, wind, solar and wind+solar."
    '''
    #set figure size
    plt.figure(figsize=(15, 10))
    plt.subplots_adjust(left=0.125, bottom=0.01, right=0.9, top=0.9, wspace=0.2, hspace=0.3)
    

    #create first subplot (consumption)
    plt.subplot(221)
    ops['Consumption'].plot.hist(color = 'lightgreen', edgecolor = 'darkblue')
    plt.title('Distribution of Consumption')
    plt.xlabel('Consumption')
    
    #create second subplot (wind)
    plt.subplot (222)
    ops['Wind'].plot.hist(color = 'lightgreen', edgecolor = 'darkblue')
    plt.title('Distribution of Wind')
    plt.xlabel('Wind')
    
    #create third subplot (solar)
    plt.subplot(223)
    ops['Solar'].plot.hist(color = 'lightgreen', edgecolor = 'darkblue')
    plt.title('Distribution of Solar')
    plt.xlabel('Solar')
    
    #create second subplot (wind)
    plt.subplot (224)
    ops['Wind+Solar'].plot.hist(color = 'lightgreen', edgecolor = 'darkblue')
    plt.title('Distribution of Wind+Solar')
    plt.xlabel('Wind+Solar')
          
    plt.show()
    return

plot_dist()

# %% [markdown]
# 3. Set the index to be the datetime variable.

# %%
# This was done as a apart of the function executed in question #1.
ops.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN
# 2006-01-02     1380.521   NaN    NaN         NaN
# 2006-01-03     1442.533   NaN    NaN         NaN
# 2006-01-04     1457.217   NaN    NaN         NaN
# 2006-01-05     1477.131   NaN    NaN         NaN

# %% [markdown]
# 4. Add a month and a year column to your dataframe.

# %%
def month_yr():
    '''
    This function adds a column specifying month and year based on the index value.
    '''
    ops['Month'] = ops.index.month
    ops['Year'] = ops.index.year
    return ops

ops = month_yr()
ops.head()
# Out:
#             Consumption  Wind  Solar  Wind+Solar  Month  Year
# Date
# 2006-01-01     1069.184   NaN    NaN         NaN      1  2006
# 2006-01-02     1380.521   NaN    NaN         NaN      1  2006
# 2006-01-03     1442.533   NaN    NaN         NaN      1  2006
# 2006-01-04     1457.217   NaN    NaN         NaN      1  2006
# 2006-01-05     1477.131   NaN    NaN         NaN      1  2006

# %% [markdown]
# 5. Fill any missing values.

# %%
ops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4383 entries, 2006-01-01 to 2017-12-31
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Consumption  4383 non-null   float64
#  1   Wind         2920 non-null   float64
#  2   Solar        2188 non-null   float64
#  3   Wind+Solar   2187 non-null   float64
#  4   Month        4383 non-null   int64
#  5   Year         4383 non-null   int64
# dtypes: float64(4), int64(2)
# memory usage: 239.7 KB

# %%
ops = ops.fillna(axis = 1, method = 'bfill')
ops
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Month    Year
# Date
# 2006-01-01   1069.18400    1.000   1.000       1.000    1.0  2006.0
# 2006-01-02   1380.52100    1.000   1.000       1.000    1.0  2006.0
# 2006-01-03   1442.53300    1.000   1.000       1.000    1.0  2006.0
# 2006-01-04   1457.21700    1.000   1.000       1.000    1.0  2006.0
# 2006-01-05   1477.13100    1.000   1.000       1.000    1.0  2006.0
# ...                 ...      ...     ...         ...    ...     ...
# 2017-12-27   1263.94091  394.507  16.530     411.037   12.0  2017.0
# 2017-12-28   1299.86398  506.424  14.162     520.586   12.0  2017.0
# 2017-12-29   1295.08753  584.277  29.854     614.131   12.0  2017.0
# 2017-12-30   1215.44897  721.247   7.467     728.714   12.0  2017.0
# 2017-12-31   1107.11488  721.176  19.980     741.156   12.0  2017.0
#
# [4383 rows x 6 columns]

# %%
ops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4383 entries, 2006-01-01 to 2017-12-31
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Consumption  4383 non-null   float64
#  1   Wind         4383 non-null   float64
#  2   Solar        4383 non-null   float64
#  3   Wind+Solar   4383 non-null   float64
#  4   Month        4383 non-null   float64
#  5   Year         4383 non-null   float64
# dtypes: float64(6)
# memory usage: 239.7 KB

# %%
ops.value_counts("Solar")
# Out:
# Solar
# 3.000      190
# 1.000      186
# 10.000     186
# 5.000      186
# 8.000      186
#           ...
# 119.870      1
# 119.927      1
# 119.949      1
# 120.002      1
# 85.779       1
# Length: 2197, dtype: int64

# %%
ops.value_counts('Wind+Solar')
# Out:
# Wind+Solar
# 3.000      191
# 1.000      186
# 8.000      186
# 12.000     186
# 5.000      186
#           ...
# 296.422      1
# 296.610      1
# 296.936      1
# 296.979      1
# 240.291      1
# Length: 2198, dtype: int64

# %%
ops['Wind+Solar'] = ops.Wind + ops.Solar
ops
# Out:
#             Consumption     Wind   Solar  Wind+Solar  Month    Year
# Date
# 2006-01-01   1069.18400    1.000   1.000       2.000    1.0  2006.0
# 2006-01-02   1380.52100    1.000   1.000       2.000    1.0  2006.0
# 2006-01-03   1442.53300    1.000   1.000       2.000    1.0  2006.0
# 2006-01-04   1457.21700    1.000   1.000       2.000    1.0  2006.0
# 2006-01-05   1477.13100    1.000   1.000       2.000    1.0  2006.0
# ...                 ...      ...     ...         ...    ...     ...
# 2017-12-27   1263.94091  394.507  16.530     411.037   12.0  2017.0
# 2017-12-28   1299.86398  506.424  14.162     520.586   12.0  2017.0
# 2017-12-29   1295.08753  584.277  29.854     614.131   12.0  2017.0
# 2017-12-30   1215.44897  721.247   7.467     728.714   12.0  2017.0
# 2017-12-31   1107.11488  721.176  19.980     741.156   12.0  2017.0
#
# [4383 rows x 6 columns]

# %% [markdown]
# 6. Make sure all the work that you have done above is reproducible. That is, you should put the code above into separate functions and be able to re-run the functions and get the same results.
